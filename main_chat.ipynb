# %%
# !unzip ONJ_P.zip
# Out:
# Archive:  ONJ_P.zip
# replace ONJ_P/requirements.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !pip install sentence-transformers
# !pip install bitsandbytes accelerate
# !pip install faiss-gpu langchain langchain_community

# %%
import sys
sys.path.append("/content/ONJ_P/source/utils")

from character_chat import Character_chat
from retrieval import Book


# EXAMPLARY USAGE
book_path = "/content/ONJ_P/data/hamlet.txt"
book = Book(book_path)
context_strategy = {"add_ner": True, "num_peaks": 2, "context_size": 1000}
# ENTER CHARACTER NAME (e.g. "HAMLET" or "OPHELIA" or "GHOST") AND LITERARY WORK NAME
chararcter_chat = Character_chat(character_name="HAMLET", book=book, book_name="HAMLET", context_strategy=context_strategy)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...

# %%
# ENTER QUESTION
question = "What is the meaning of life?"
# GET ANSWER
answer = chararcter_chat.get_response(question)
print(answer)
# Out:
# "To be, or not to be, that is the question..."
